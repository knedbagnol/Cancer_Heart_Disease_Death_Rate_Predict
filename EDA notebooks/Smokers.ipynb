# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
import addfips

# %%
smokers = pd.read_csv('./datasets/smokers.csv')
smokers
# Out:
#              State  Percent_smokers_2018
# 0          Alabama                  19.2
# 1           Alaska                  19.1
# 2          Arizona                  14.0
# 3         Arkansas                  22.7
# 4       California                  11.2
# 5         Colorado                  14.5
# 6      Connecticut                  12.2
# 7         Delaware                  16.5
# 8          Florida                  14.5
# 9          Georgia                  16.1
# 10            Guam                  21.9
# 11          Hawaii                  13.4
# 12           Idaho                  14.7
# 13        Illinois                  15.5
# 14         Indiana                  21.1
# 15            Iowa                  16.6
# 16          Kansas                  17.2
# 17        Kentucky                  23.4
# 18       Louisiana                  20.5
# 19           Maine                  17.8
# 20        Maryland                  12.5
# 21   Massachusetts                  13.4
# ...

# %%
remove = ['Guam', 'Puerto Rico']

smokers = smokers[~smokers['State'].isin(remove)]

smokers
# Out:
#              State  Percent_smokers_2018
# 0          Alabama                  19.2
# 1           Alaska                  19.1
# 2          Arizona                  14.0
# 3         Arkansas                  22.7
# 4       California                  11.2
# 5         Colorado                  14.5
# 6      Connecticut                  12.2
# 7         Delaware                  16.5
# 8          Florida                  14.5
# 9          Georgia                  16.1
# 11          Hawaii                  13.4
# 12           Idaho                  14.7
# 13        Illinois                  15.5
# 14         Indiana                  21.1
# 15            Iowa                  16.6
# 16          Kansas                  17.2
# 17        Kentucky                  23.4
# 18       Louisiana                  20.5
# 19           Maine                  17.8
# 20        Maryland                  12.5
# 21   Massachusetts                  13.4
# 22        Michigan                  18.9
# ...

# %%
smokers.to_csv('./datasets/smokers.csv')
